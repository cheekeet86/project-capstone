# %% [markdown]
# ### Contents
#
# - [EDA](#EDA)

# %% [markdown]
# ### Header

# %%
# user configuration

# %%
# import libraries

# maths
import scipy.stats as stats
import numpy as np
import pandas as pd
#from pandas.api.types import is_numeric_dtype

# visual
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# html
from IPython.display import Image
from IPython.core.display import HTML

# web
import json

# others
from tqdm import tqdm
import datetime as dt
#import re
import os

# %%
# file paths

folder = 'fitrec/'

input_path = '../data/1_input/' + folder
clean_path = '../data/2_clean/' + folder
preprocess_path = '../data/3_preprocess/' + folder
output_path = '../data/4_output/' + folder

# %% [markdown]
# ### Import Data

# %%
# import clean data

# file = 'endomondoHR_proper_head_1000.json'
# file = 'endomondoHR_proper_head_10000.json'

# path = input_path + file

# with open(path, "r") as read_file:
#     data = json.load(read_file)

# %% [markdown]
# ### Functions

# %%
def create_df(data):
    
    #cols = ['id','userId','gender','timestamp','sport','speed','heart_rate','latitude','longitude','altitude']
    df = pd.DataFrame()
    
    index = 0

    for key,val in data.items():
    
        #print(index)

        df.at[index,'id'] = key
        df.at[index,'userId'] = val['userId']
        df.at[index,'gender'] = val['gender']
        df.at[index,'sport'] = val['sport']

        timestamp = val['timestamp']
        heart_rate = val['heart_rate']
        latitude = val['latitude']
        longitude = val['longitude']
        altitude = val['altitude']   

        df.at[index,'time_start'] = np.min(timestamp)
        df.at[index,'time_end'] = np.max(timestamp)
        df.at[index,'time_dur'] = (np.max(timestamp) - np.min(timestamp))/60

        df.at[index,'lat_start'] = latitude[0]
        df.at[index,'lat_end'] = latitude[-1]

        df.at[index,'lon_start'] = longitude[0]
        df.at[index,'lon_end'] = longitude[-1]

        df.at[index,'alt_avg'] = np.mean(altitude)
        df.at[index,'alt_min'] = np.min(altitude)
        df.at[index,'alt_q1'] = np.quantile(altitude,0.25)
        df.at[index,'alt_q3'] = np.quantile(altitude,0.75)
        df.at[index,'alt_max'] = np.max(altitude)

        df.at[index,'hr_avg'] = np.mean(heart_rate)
        df.at[index,'hr_min'] = np.min(heart_rate)
        df.at[index,'hr_q1'] = np.quantile(heart_rate,0.25)
        df.at[index,'hr_q3'] = np.quantile(heart_rate,0.75)
        df.at[index,'hr_max'] = np.max(heart_rate)

        if 'speed' in val.keys():
            speed = val['speed']

            df.at[index,'spd_avg'] = np.mean(speed)
            df.at[index,'spd_min'] = np.min(speed)
            df.at[index,'spd_q1'] = np.quantile(speed,0.25)
            df.at[index,'spd_q3'] = np.quantile(speed,0.75)
            df.at[index,'spd_max'] = np.max(speed)

        index += 1
        
    return df

# %% [markdown]
# ### Import Json and Create/Output df

# %%
# select json file for splitting

#file_index = 0
#file_index = 1
file_index = 2

input_filepath = [
            "endomondoHR/",
            "endomondoMeta/",
            "endomondoHR_proper/",
            #"processed_endomondoHR_proper/",
            #"processed_endomondoHR_proper_interpolate/"        
            ]


output_filepath = [
            "endomondoHR_summary.csv",
            "endomondoMeta_summary.csv",
            "endomondoHR_proper_summary.csv",
            #"processed_endomondoHR_proper_summary.csv",
            #"processed_endomondoHR_proper_interpolate_summary.csv"        
            ]

# init filepaths

in_path = input_path + input_filepath[file_index]
out_path = clean_path + output_filepath[file_index]

print(in_path)
print(out_path)
# Out:
# ../data/1_input/fitrec/endomondoHR_proper/
# ../data/2_clean/fitrec/endomondoHR_proper_summary.csv

# %%
df_all = pd.DataFrame()

files = os.listdir(in_path)

for file in files:
    
    print(file)
    path = in_path + file
    
    with open(path, "r") as read_file:
        
        # load each json file
        data = json.load(read_file)
        
        # create summary for json
        df_json = create_df(data)
        
        # combine summary to df_all
        df_all = df_all.append(df_json,ignore_index=True)
# Out:
# endomondoHR_proper_001.json
# endomondoHR_proper_002.json
# endomondoHR_proper_003.json
# endomondoHR_proper_004.json
# endomondoHR_proper_005.json
# endomondoHR_proper_006.json
# endomondoHR_proper_007.json
# endomondoHR_proper_008.json
# endomondoHR_proper_009.json
# endomondoHR_proper_010.json
# endomondoHR_proper_011.json
# endomondoHR_proper_012.json
# endomondoHR_proper_013.json
# endomondoHR_proper_014.json
# endomondoHR_proper_015.json
# endomondoHR_proper_016.json
# endomondoHR_proper_017.json
# endomondoHR_proper_018.json
# endomondoHR_proper_019.json
# endomondoHR_proper_020.json
# endomondoHR_proper_021.json
# endomondoHR_proper_022.json
# endomondoHR_proper_023.json
# endomondoHR_proper_024.json
# endomondoHR_proper_025.json
# endomondoHR_proper_026.json
# endomondoHR_proper_027.json
# endomondoHR_proper_028.json
# endomondoHR_proper_029.json
# endomondoHR_proper_030.json
# endomondoHR_proper_031.json
# endomondoHR_proper_032.json
# endomondoHR_proper_033.json
# endomondoHR_proper_034.json
# endomondoHR_proper_035.json
# endomondoHR_proper_036.json
# endomondoHR_proper_037.json
# endomondoHR_proper_038.json
# endomondoHR_proper_039.json
# endomondoHR_proper_040.json
# endomondoHR_proper_041.json
# endomondoHR_proper_042.json
# endomondoHR_proper_043.json
# endomondoHR_proper_044.json
# endomondoHR_proper_045.json
# endomondoHR_proper_046.json
# endomondoHR_proper_047.json
# endomondoHR_proper_048.json
# endomondoHR_proper_049.json
# endomondoHR_proper_050.json
# endomondoHR_proper_051.json
# endomondoHR_proper_052.json
# endomondoHR_proper_053.json
# endomondoHR_proper_054.json
# endomondoHR_proper_055.json
# endomondoHR_proper_056.json
# endomondoHR_proper_057.json
# endomondoHR_proper_058.json
# endomondoHR_proper_059.json
# endomondoHR_proper_060.json
# endomondoHR_proper_061.json
# endomondoHR_proper_062.json
# endomondoHR_proper_063.json
# endomondoHR_proper_064.json
# endomondoHR_proper_065.json
# endomondoHR_proper_066.json
# endomondoHR_proper_067.json
# endomondoHR_proper_068.json
# endomondoHR_proper_069.json
# endomondoHR_proper_070.json
# endomondoHR_proper_071.json
# endomondoHR_proper_072.json
# endomondoHR_proper_073.json
# endomondoHR_proper_074.json
# endomondoHR_proper_075.json
# endomondoHR_proper_076.json
# endomondoHR_proper_077.json
# endomondoHR_proper_078.json
# endomondoHR_proper_079.json
# endomondoHR_proper_080.json
# endomondoHR_proper_081.json
# endomondoHR_proper_082.json
# endomondoHR_proper_083.json
# endomondoHR_proper_084.json
# endomondoHR_proper_085.json
# endomondoHR_proper_086.json
# endomondoHR_proper_087.json
# endomondoHR_proper_088.json
# endomondoHR_proper_089.json
# endomondoHR_proper_090.json
# endomondoHR_proper_091.json
# endomondoHR_proper_092.json
# endomondoHR_proper_093.json
# endomondoHR_proper_094.json
# endomondoHR_proper_095.json
# endomondoHR_proper_096.json
# endomondoHR_proper_097.json
# endomondoHR_proper_098.json
# endomondoHR_proper_099.json
# endomondoHR_proper_100.json
# endomondoHR_proper_101.json
# endomondoHR_proper_102.json
# endomondoHR_proper_103.json
# endomondoHR_proper_104.json
# endomondoHR_proper_105.json
# endomondoHR_proper_106.json
# endomondoHR_proper_107.json
# endomondoHR_proper_108.json
# endomondoHR_proper_109.json
# endomondoHR_proper_110.json
# endomondoHR_proper_111.json
# endomondoHR_proper_112.json
# endomondoHR_proper_113.json
# endomondoHR_proper_114.json
# endomondoHR_proper_115.json
# endomondoHR_proper_116.json
# endomondoHR_proper_117.json
# endomondoHR_proper_118.json
# endomondoHR_proper_119.json
# endomondoHR_proper_120.json
# endomondoHR_proper_121.json
# endomondoHR_proper_122.json
# endomondoHR_proper_123.json
# endomondoHR_proper_124.json
# endomondoHR_proper_125.json
# endomondoHR_proper_126.json
# endomondoHR_proper_127.json
# endomondoHR_proper_128.json
# endomondoHR_proper_129.json
# endomondoHR_proper_130.json
# endomondoHR_proper_131.json
# endomondoHR_proper_132.json
# endomondoHR_proper_133.json
# endomondoHR_proper_134.json
# endomondoHR_proper_135.json
# endomondoHR_proper_136.json
# endomondoHR_proper_137.json
# endomondoHR_proper_138.json
# endomondoHR_proper_139.json
# endomondoHR_proper_140.json
# endomondoHR_proper_141.json
# endomondoHR_proper_142.json
# endomondoHR_proper_143.json
# endomondoHR_proper_144.json
# endomondoHR_proper_145.json
# endomondoHR_proper_146.json
# endomondoHR_proper_147.json
# endomondoHR_proper_148.json
# endomondoHR_proper_149.json
# endomondoHR_proper_150.json
# endomondoHR_proper_151.json
# endomondoHR_proper_152.json
# endomondoHR_proper_153.json
# endomondoHR_proper_154.json
# endomondoHR_proper_155.json
# endomondoHR_proper_156.json
# endomondoHR_proper_157.json
# endomondoHR_proper_158.json
# endomondoHR_proper_159.json
# endomondoHR_proper_160.json
# endomondoHR_proper_161.json
# endomondoHR_proper_162.json
# endomondoHR_proper_163.json
# endomondoHR_proper_164.json
# endomondoHR_proper_165.json
# endomondoHR_proper_166.json
# endomondoHR_proper_167.json
# endomondoHR_proper_168.json

# %% [markdown]
# ### Verify df

# %%
df_all
# Out:
#             id      userId gender             sport    time_start  \
# 0            1  10921915.0   male              bike  1.408899e+09
# 1            2  10921915.0   male              bike  1.408222e+09
# 2            3  10921915.0   male              bike  1.407858e+09
# 3            4  10921915.0   male              bike  1.407432e+09
# 4            5  10921915.0   male  bike (transport)  1.406909e+09
# 5            6  10921915.0   male  bike (transport)  1.406665e+09
# 6            7  10921915.0   male  bike (transport)  1.406647e+09
# 7            8  10921915.0   male  bike (transport)  1.406581e+09
# 8            9  10921915.0   male              bike  1.405282e+09
# 9           10  10921915.0   male              bike  1.405101e+09
# 10          11  10921915.0   male              bike  1.404774e+09
# 11          12  10921915.0   male  bike (transport)  1.404492e+09
# 12          13  10921915.0   male              bike  1.404415e+09
# 13          14  10921915.0   male              bike  1.404322e+09
# 14          15  10921915.0   male              bike  1.403536e+09
# 15          16  10921915.0   male              bike  1.403465e+09
# 16          17  10921915.0   male              bike  1.403285e+09
# 17          18  10921915.0   male              bike  1.403115e+09
# 18          19  10921915.0   male              bike  1.403029e+09
# 19          20  10921915.0   male              bike  1.402943e+09
# 20          21  10921915.0   male              bike  1.402768e+09
# 21          22  10921915.0   male              bike  1.401902e+09
# 22          23  10921915.0   male              bike  1.401633e+09
# 23          24  10921915.0   male              bike  1.400628e+09
# 24          25  10921915.0   male              bike  1.398700e+09
# 25          26  10921915.0   male              bike  1.398017e+09
# 26          27  10921915.0   male  bike (transport)  1.398015e+09
# 27          28  10921915.0   male              bike  1.397838e+09
# 28          29  10921915.0   male              bike  1.397427e+09
# 29          30   4969375.0   male               run  1.397079e+09
# ...        ...         ...    ...               ...           ...
# 167753  167754        69.0   male              bike  1.438364e+09
# 167754  167755        69.0   male              bike  1.437003e+09
# 167755  167756        69.0   male              bike  1.435693e+09
# 167756  167757        69.0   male              bike  1.435438e+09
# 167757  167758        69.0   male              bike  1.435319e+09
# 167758  167759        69.0   male              bike  1.434746e+09
# 167759  167760        69.0   male               run  1.405634e+09
# 167760  167761        69.0   male     mountain bike  1.402590e+09
# 167761  167762        69.0   male               run  1.399472e+09
# 167762  167763        69.0   male               run  1.397736e+09
# 167763  167764        69.0   male               run  1.397421e+09
# 167764  167765        69.0   male               run  1.396273e+09
# 167765  167766        69.0   male               run  1.396195e+09
# 167766  167767        69.0   male               run  1.393000e+09
# 167767  167768        69.0   male               run  1.392922e+09
# 167768  167769        69.0   male               run  1.377401e+09
# 167769  167770        69.0   male               run  1.377353e+09
# 167770  167771        69.0   male               run  1.375229e+09
# 167771  167772        69.0   male               run  1.368452e+09
# 167772  167773        69.0   male               run  1.368105e+09
# 167773  167774        69.0   male               run  1.363271e+09
# 167774  167775        69.0   male               run  1.361547e+09
# 167775  167776        69.0   male               run  1.361201e+09
# 167776  167777        69.0   male               run  1.357906e+09
# 167777  167778        69.0   male               run  1.333545e+09
# 167778  167779        69.0   male               run  1.323017e+09
# 167779  167780        69.0   male              bike  1.320185e+09
# 167780  167781        69.0   male               run  1.317828e+09
# 167781  167782        69.0   male              bike  1.314372e+09
# 167782  167783        69.0   male               run  1.314153e+09
#
#             time_end    time_dur  lat_start    lat_end   lon_start  ...  \
# 0       1.408906e+09  126.483333  60.173349  60.173354   24.649770  ...
# 1       1.408226e+09   74.000000  60.173248  60.173344   24.649855  ...
# 2       1.407865e+09  112.483333  60.173262  60.173366   24.649957  ...
# 3       1.407437e+09   75.316667  60.173286  60.173303   24.649874  ...
# 4       1.406911e+09   22.616667  60.173293  60.183756   24.649798  ...
# 5       1.406667e+09   33.666667  60.183585  60.173346   24.817700  ...
# 6       1.406649e+09   23.750000  60.173279  60.183718   24.649817  ...
# 7       1.406583e+09   33.216667  60.183662  60.173386   24.817467  ...
# 8       1.405295e+09  216.916667  60.173318  60.173332   24.649676  ...
# 9       1.405105e+09   73.700000  60.173246  60.173441   24.650183  ...
# 10      1.404778e+09   59.466667  60.173277  60.173355   24.649821  ...
# 11      1.404498e+09   99.450000  60.173326  60.173372   24.649684  ...
# 12      1.404422e+09  112.833333  60.173228  60.173352   24.649703  ...
# 13      1.404326e+09   56.700000  60.173366  60.173365   24.649791  ...
# 14      1.403540e+09   73.900000  60.173290  60.173353   24.649662  ...
# 15      1.403472e+09  117.450000  60.173285  60.173328   24.649720  ...
# 16      1.403290e+09   77.600000  60.173243  60.173360   24.649847  ...
# 17      1.403122e+09  117.933333  60.173297  60.173365   24.649711  ...
# 18      1.403033e+09   57.183333  60.173307  60.173353   24.649716  ...
# 19      1.402947e+09   61.516667  60.173306  60.173351   24.649784  ...
# 20      1.402775e+09  103.083333  60.173167  60.173331   24.649824  ...
# 21      1.401906e+09   67.450000  60.173351  60.173341   24.649987  ...
# 22      1.401644e+09  172.483333  60.173343  60.173324   24.649767  ...
# 23      1.400632e+09   55.400000  60.174253  60.173361   24.650152  ...
# 24      1.398706e+09  102.050000  60.173179  60.173353   24.650005  ...
# 25      1.398022e+09   71.883333  60.173256  60.173348   24.649934  ...
# 26      1.398017e+09   34.783333  60.173251  60.173368   24.649928  ...
# 27      1.397850e+09  199.166667  60.173268  60.173319   24.649790  ...
# 28      1.397430e+09   39.350000  60.173259  60.173421   24.649815  ...
# 29      1.397083e+09   64.800000  52.222681  52.224028    6.885493  ...
# ...              ...         ...        ...        ...         ...  ...
# 167753  1.438365e+09   21.433333 -11.639403 -11.636592  166.948344  ...
# 167754  1.437012e+09  157.000000  55.240795  55.240719   11.764714  ...
# 167755  1.435698e+09   90.650000  55.565861  55.240700   11.970893  ...
# 167756  1.435443e+09   90.433333  55.565739  55.240662   11.971519  ...
# 167757  1.435325e+09   93.266667  55.240715  55.565815   11.764759  ...
# 167758  1.434754e+09  121.550000  55.565769  55.240704   11.971566  ...
# 167759  1.405643e+09  148.833333  55.236961  55.240641   11.763610  ...
# 167760  1.402596e+09   92.900000  55.240627  55.240601   11.764864  ...
# 167761  1.399477e+09   87.683333  55.240770  55.240808   11.764800  ...
# 167762  1.397738e+09   37.100000  50.109307  50.109372   14.451265  ...
# 167763  1.397424e+09   52.216667  50.109215  50.109281   14.451339  ...
# 167764  1.396275e+09   38.900000  55.240705  55.227682   11.764768  ...
# 167765  1.396200e+09   81.600000  55.240800  55.240816   11.764797  ...
# 167766  1.393002e+09   39.433333  55.240681  55.240780   11.764526  ...
# 167767  1.392924e+09   34.116667  55.240851  55.240785   11.764631  ...
# 167768  1.377409e+09  123.116667  55.248561  55.248615   11.757077  ...
# 167769  1.377367e+09  235.100000  55.391509  55.391546   12.037592  ...
# 167770  1.375234e+09   84.716667  55.234609  55.234588   11.757300  ...
# 167771  1.368469e+09  297.450000  55.231777  55.231718   11.787504  ...
# 167772  1.368120e+09  255.166667  55.641720  55.641719   12.646442  ...
# 167773  1.363288e+09  291.200000  55.231759  55.231740   11.787489  ...
# 167774  1.361563e+09  272.583333  55.231760  55.231699   11.787496  ...
# 167775  1.361218e+09  282.800000  55.231759  55.231701   11.787540  ...
# 167776  1.357912e+09  113.300000  55.240766  55.240839   11.764839  ...
# 167777  1.333550e+09   85.366667  55.240803  55.240852   11.764875  ...
# 167778  1.323018e+09   11.666667  55.251061  55.249166   11.765998  ...
# 167779  1.320188e+09   56.483333  55.239426  55.240711   11.768504  ...
# 167780  1.317829e+09   12.000000  55.298614  55.317114   11.572907  ...
# 167781  1.314376e+09   68.416667  55.240333  55.240690   11.764165  ...
# 167782  1.314155e+09   29.816667  55.240675  55.240625   11.764669  ...
#
#          hr_avg  hr_min   hr_q1   hr_q3  hr_max    spd_avg  spd_min   spd_q1  \
# 0       152.650   100.0  146.00  160.00   177.0  26.162158   3.8592  19.8972
# 1       147.710   100.0  140.00  156.00   174.0  27.218369   8.0820  21.8106
# 2       140.554    99.0  133.00  149.00   168.0  26.050774   0.0000  20.5992
# 3       147.020    99.0  140.00  155.00   178.0  26.877838   4.3272  21.4848
# 4       167.154   110.0  164.00  174.00   183.0        NaN      NaN      NaN
# 5       148.120   106.0  138.00  159.00   179.0        NaN      NaN      NaN
# 6       166.084   118.0  162.00  174.00   185.0  29.592281   7.2180  23.7726
# 7       144.794   112.0  134.00  155.00   179.0  21.673174   6.8040  16.2369
# 8       137.804    90.0  129.00  148.00   184.0        NaN      NaN      NaN
# 9       145.914    98.0  137.00  156.00   178.0  27.497556  11.6820  21.7278
# 10      148.770   103.0  137.00  161.00   181.0        NaN      NaN      NaN
# 11      146.814    99.0  134.75  158.00   183.0        NaN      NaN      NaN
# 12      143.224    91.0  133.00  152.25   179.0  25.193405   0.0000  19.0710
# 13      143.854    98.0  132.00  153.00   178.0        NaN      NaN      NaN
# 14      155.236    99.0  148.00  164.00   176.0  27.228132   0.0000  21.2634
# 15      142.762   102.0  136.00  150.00   168.0  24.542734   0.0000  19.3644
# 16      137.846    93.0  130.00  146.00   167.0        NaN      NaN      NaN
# 17      146.102    92.0  139.00  155.00   180.0  26.581320   0.0000  21.4038
# 18      131.688    86.0  121.00  140.00   170.0        NaN      NaN      NaN
# 19      140.456    98.0  130.00  150.00   175.0        NaN      NaN      NaN
# 20      143.856    94.0  137.00  153.25   174.0        NaN      NaN      NaN
# 21      155.790   101.0  151.00  162.00   172.0  29.745864   0.0000  24.4152
# 22      149.152   103.0  140.00  159.25   175.0        NaN      NaN      NaN
# 23      133.262    90.0  123.00  144.25   163.0  27.026460   6.9228  22.5918
# 24      134.466   102.0  125.75  143.00   162.0        NaN      NaN      NaN
# 25      154.416   102.0  151.00  162.00   172.0  27.926554   8.7408  22.9860
# 26      104.736    81.0   94.00  115.00   128.0  15.880759   0.0000  10.4508
# 27      133.150    92.0  126.00  144.00   169.0        NaN      NaN      NaN
# 28      144.556   101.0  138.00  153.00   172.0        NaN      NaN      NaN
# 29      122.104    65.0   90.00  153.00   227.0        NaN      NaN      NaN
# ...         ...     ...     ...     ...     ...        ...      ...      ...
# 167753  155.380   106.0  153.75  159.00   168.0        NaN      NaN      NaN
# 167754  150.042    92.0  145.00  159.00   167.0        NaN      NaN      NaN
# 167755  147.408   101.0  143.00  155.00   164.0        NaN      NaN      NaN
# 167756  140.582    83.0  136.00  149.00   158.0        NaN      NaN      NaN
# 167757  144.992    93.0  140.00  152.00   163.0        NaN      NaN      NaN
# 167758  136.880    91.0  130.00  146.00   156.0        NaN      NaN      NaN
# 167759  133.646   100.0  125.00  142.00   164.0        NaN      NaN      NaN
# 167760  133.700    79.0  125.00  145.00   160.0        NaN      NaN      NaN
# 167761  136.934    72.0  135.00  143.00   155.0        NaN      NaN      NaN
# 167762  125.480    71.0  120.75  134.00   154.0        NaN      NaN      NaN
# 167763  131.966    70.0  122.00  145.00   160.0        NaN      NaN      NaN
# 167764  157.312    81.0  153.00  161.00   182.0        NaN      NaN      NaN
# 167765  153.106    91.0  151.00  160.00   165.0        NaN      NaN      NaN
# 167766  146.148    91.0  141.00  154.00   167.0        NaN      NaN      NaN
# 167767  155.294    99.0  152.00  160.00   171.0        NaN      NaN      NaN
# 167768  134.108    78.0  134.00  138.00   151.0        NaN      NaN      NaN
# 167769  147.990    84.0  145.00  152.00   170.0        NaN      NaN      NaN
# 167770  139.020    89.0  129.00  150.25   179.0        NaN      NaN      NaN
# 167771  128.718    74.0  124.00  134.00   155.0        NaN      NaN      NaN
# 167772  151.948    71.0  149.00  158.00   163.0        NaN      NaN      NaN
# 167773  143.498    75.0  140.00  149.00   158.0        NaN      NaN      NaN
# 167774  137.992    82.0  128.00  150.00   166.0        NaN      NaN      NaN
# 167775  149.182    79.0  144.00  158.00   166.0        NaN      NaN      NaN
# 167776  142.248    80.0  138.00  147.00   155.0        NaN      NaN      NaN
# 167777  140.498    76.0  135.00  144.00   168.0        NaN      NaN      NaN
# 167778  169.894    98.0  172.00  175.00   178.0        NaN      NaN      NaN
# 167779  108.846    81.0   93.00  136.00   157.0        NaN      NaN      NaN
# 167780  160.842   102.0  161.00  166.00   170.0        NaN      NaN      NaN
# 167781  113.518    81.0  103.00  124.00   137.0        NaN      NaN      NaN
# 167782  157.656   139.0  156.00  159.00   164.0        NaN      NaN      NaN
#
#          spd_q3  spd_max
# 0       31.7313  57.4596
# 1       31.9257  54.7704
# 2       31.0365  59.2092
# 3       31.2651  57.9852
# 4           NaN      NaN
# 5           NaN      NaN
# 6       35.2998  50.9724
# 7       26.0046  49.1436
# 8           NaN      NaN
# 9       32.4873  57.7404
# 10          NaN      NaN
# 11          NaN      NaN
# 12      30.6288  52.3152
# 13          NaN      NaN
# 14      32.2101  58.4460
# 15      29.0223  44.7732
# 16          NaN      NaN
# 17      31.7160  50.9508
# 18          NaN      NaN
# 19          NaN      NaN
# 20          NaN      NaN
# 21      34.7256  58.5072
# 22          NaN      NaN
# 23      31.0761  43.2360
# 24          NaN      NaN
# 25      31.9779  57.6684
# 26      20.7387  34.0020
# 27          NaN      NaN
# 28          NaN      NaN
# 29          NaN      NaN
# ...         ...      ...
# 167753      NaN      NaN
# 167754      NaN      NaN
# 167755      NaN      NaN
# 167756      NaN      NaN
# 167757      NaN      NaN
# 167758      NaN      NaN
# 167759      NaN      NaN
# 167760      NaN      NaN
# 167761      NaN      NaN
# 167762      NaN      NaN
# 167763      NaN      NaN
# 167764      NaN      NaN
# 167765      NaN      NaN
# 167766      NaN      NaN
# 167767      NaN      NaN
# 167768      NaN      NaN
# 167769      NaN      NaN
# 167770      NaN      NaN
# 167771      NaN      NaN
# 167772      NaN      NaN
# 167773      NaN      NaN
# 167774      NaN      NaN
# 167775      NaN      NaN
# 167776      NaN      NaN
# 167777      NaN      NaN
# 167778      NaN      NaN
# 167779      NaN      NaN
# 167780      NaN      NaN
# 167781      NaN      NaN
# 167782      NaN      NaN
#
# [167783 rows x 26 columns]

# %% [markdown]
# ### Output df

# %%
# output combined df to csv

df_all.to_csv(out_path,index=False)
